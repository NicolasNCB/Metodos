# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sm

# %% [markdown]
# Tiempo Transmisión
# Para encontrar el mínimo se debe optimizar la función con su derivada.

# %%
def tiempo_viaje (distancia:float)->float:
  salida=(3*10**8)*np.sqrt((distancia+3)**2+(2)**2)+((3*10**8)/1.33)*np.sqrt((distancia-2)**2+(-2)**2)
  return salida

# %%
ejemplos=np.linspace(-2,-1,100)
salidas=[]
for n in ejemplos:
  salidas.append(tiempo_viaje(n))
print(salidas)
plt.plot(ejemplos,salidas)
# Out:
# [1679572864.3024735, 1678896153.3594615, 1678231362.6010447, 1677578431.9797912, 1676937301.5176044, 1676307911.3164828, 1675690201.5690901, 1675084112.569128, 1674489584.7215137, 1673906558.552361, 1673334974.7187662, 1672774774.018403, 1672225897.3989124, 1671688285.9671097, 1671161880.9979904, 1670646623.9435444, 1670142456.4413805, 1669649320.3231547, 1669167157.6228154, 1668695910.5846505, 1668235521.6711562, 1667785933.5707104, 1667347089.2050686, 1666918931.7366705, 1666501404.5757685, 1666094451.3873727, 1665698016.0980203, 1665312042.9023676, 1664936476.2696037, 1664571260.9496975, 1664216341.9794672, 1663871664.6884866, 1663537174.7048187, 1663212817.9605923, 1662898540.6974077, 1662594289.4715872, 1662300011.1592674, 1662015652.9613347, 1661741162.4082065, 1661476487.3644629, 1661221576.0333295, 1660976376.9610143, 1660740839.0408974, 1660514911.5175853, 1660298543.9908206, 1660091686.4192586, 1659894289.124107, 1659706302.7926378, 1659527678.481567, 1659358367.6203074, 16
# ...

# %% [markdown]
# Newton-Raphson para mímino

# %%
def derivada(x:float)->float:
  salida=((3*10*8*x+9*10**8)/np.sqrt(x**2+6*x+13))+((300*10**8*x+900*10*8)/133*np.sqrt(x**2+6*x+13))
  return salida
def Newton(x:float)->float:
